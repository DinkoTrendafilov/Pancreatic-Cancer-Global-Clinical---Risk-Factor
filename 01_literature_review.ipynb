# %% [markdown]
# # Literature Review and Research Background
# ## Optimizing Prognostic Modeling for Pancreatic Cancer
#
# This review provides the theoretical foundation for our multi-phase survival analysis and predictive modeling pipeline. Our work bridges traditional biostatistical methods with modern machine learning to address the high lethality of Pancreatic Ductal Adenocarcinoma (PDAC).

# %% [markdown]
# ## 1. Clinical Background
# Pancreatic cancer remains a critical global health challenge. Recent estimates highlight the urgency of accurate prognosis, as late-stage diagnosis limits therapeutic options.
#
# * **Key Clinical Reference:** According to IARC's *GLOBOCAN 2022* estimates, PDAC is characterized by aggressive progression, necessitating data-driven tools for risk stratification.
#   > *Source: Sung, H., et al. (2022). Global Cancer Statistics 2022.*

# %% [markdown]
# ## 2. Statistical Methodology Foundation
# Our pipeline employs non-parametric methods to handle the time-to-event nature of our data, specifically addressing the issue of **censoring** (patients who are alive at the end of the study).
#
# * **The Kaplan-Meier Framework:** We use the Kaplan-Meier estimator as the gold standard for visualizing survival probabilities over time.
# * **Hypothesis Testing:** The Log-Rank test serves as our primary statistical tool for comparing survival distributions between independent clinical strata (e.g., tumor stages).
#   > *Source: Kaplan, E. L., & Meier, P. (1958). Nonparametric estimation from incomplete observations.*

# %% [markdown]
# ## 3. Multivariate Regression and Risk Weighting
# While non-parametric methods are excellent for visualization, they cannot account for multiple confounding variables simultaneously.
#
# * **Cox Proportional Hazards Model:** We utilize Cox regression to calculate **Hazard Ratios (HR)**, allowing us to quantify the precise impact of clinical factors like tumor stage, grade, and mutations while adjusting for other covariates.
#   > *Source: Cox, D. R. (1972). Regression Models and Life-Tables.*

# %% [markdown]
# ## 4. Transition to Predictive Machine Learning
# To maximize clinical utility, we augment statistical regression with machine learning architectures (Random Forest and XGBoost).
#
# * **Clinical Decision Support:** Unlike classical regression, which focuses on inference (Hazard Ratios), our ML models prioritize **predictive sensitivity (Recall)**. This ensures that the system identifies high-risk patients with high precision, fulfilling the requirement for proactive clinical alerts.
#   > *Source: Rajkomar, A., et al. (2018). Scalable and accurate deep learning with electronic health records.*

# %% [markdown]
# ## 5. Conclusion: Operationalizing the Literature
# This literature review anchors our project’s analytical structure in verified biostatistical practice:
#
# 1. **Phase 1 (Data):** Cleaning and stratification.
# 2. **Phase 2 (Non-Parametric):** Survival estimation via Kaplan-Meier & Log-Rank.
# 3. **Phase 3 (Semi-Parametric):** Multivariate hazard analysis via Cox Regression.
# 4. **Phase 4 (Predictive):** Machine learning pipeline for real-time risk assessment.
#
# By combining these methods, we build a robust, scalable system for pancreatic cancer prognosis.
