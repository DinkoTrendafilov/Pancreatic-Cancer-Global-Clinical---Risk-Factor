# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt 

from lifelines import WeibullFitter

# %%
cancer_data = pd.read_csv(r"C:\Users\Dell\Desktop\PancreaticCancer\pancreatic_cancer_dataset_cleaned.csv")

# %%
cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 51 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Patient_ID            2000 non-null   object
#  1   Diagnosis_Year        2000 non-null   int64
#  2   Diagnosis_Date        2000 non-null   object
#  3   WHO_Region            2000 non-null   object
#  4   Country               2000 non-null   object
#  5   Age                   2000 non-null   int64
#  6   Gender                2000 non-null   object
#  7   Ethnicity             2000 non-null   object
#  8   Smoking_Status        2000 non-null   object
#  9   Pack_Years            2000 non-null   int64
#  10  Alcohol_Use           2000 non-null   object
#  11  BMI                   2000 non-null   float64
#  12  BMI_Category          2000 non-null   object
#  13  Diabetes_Status       2000 non-null   object
#  14  Chronic_Pancreatitis  2000 non-null   object
#  15  Family_History        2000 non-null   object
#  16  Hereditary_Syndrome   2000 non-null   object
#  17  Blood_Group           2000 non-null   object
#  18  Genetic_Mutation      2000 non-null   object
#  19  Cancer_Type           2000 non-null   object
#  20  Tumor_Location        2000 non-null   object
#  21  Cancer_Stage          2000 non-null   object
#  22  Resectability         2000 non-null   object
#  23  Tumor_Size_cm         2000 non-null   float64
#  24  Tumor_Grade           2000 non-null   object
#  25  Metastasis_Site       2000 non-null   object
#  26  Biomarker_Status      2000 non-null   object
#  27  CA_19_9_Level         2000 non-null   float64
#  28  Jaundice              2000 non-null   object
#  29  Abdominal_Pain        2000 non-null   object
#  30  Back_Pain             2000 non-null   object
#  31  Weight_Loss           2000 non-null   object
#  32  Loss_of_Appetite      2000 non-null   object
#  33  Nausea_Vomiting       2000 non-null   object
#  34  New_Onset_Diabetes    2000 non-null   object
#  35  Dark_Urine            2000 non-null   object
#  36  Light_Colored_Stool   2000 non-null   object
#  37  Fatigue               2000 non-null   object
#  38  Blood_Clots           2000 non-null   object
#  39  Digestive_Problems    2000 non-null   object
#  40  Diagnosis_Method      2000 non-null   object
#  41  Treatment             2000 non-null   object
#  42  Surgery_Performed     2000 non-null   object
#  43  Surgical_Margin       2000 non-null   object
#  44  Lymph_Node_Status     2000 non-null   object
#  45  Vascular_Involvement  2000 non-null   object
#  46  Perineural_Invasion   2000 non-null   object
#  47  ECOG_Score            2000 non-null   int64
#  48  Survival_Months       2000 non-null   int64
#  49  Survived              2000 non-null   int64
#  50  Five_Year_Status      2000 non-null   object
# dtypes: float64(3), int64(6), object(42)
# memory usage: 797.0+ KB

# %%
bins = [0, 40, 50, 60, 70, 100]
labels = ["<40", "40-49", "50-59", "60-69", "70+"]

cancer_data["Age_Group"] = pd.cut(cancer_data["Age"], bins=bins, labels=labels, right=False)


print(cancer_data["Age_Group"].value_counts().sort_index())
# Out:
# Age_Group
# <40        8
# 40-49     64
# 50-59    384
# 60-69    813
# 70+      731
# Name: count, dtype: int64
